# %% [markdown]
# ## Lab 17: Linear Regression (Cardo Good Fitnesss)
# - Research Background:
#   - The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months.

# %% [markdown]
# - Research objective:
#   - Building models to related the customer features with sales

# %%
# Importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams.update({'font.size': 5}) #输出图片的字体大小

# %%
pipi = pd.read_csv('CardioGoodFitness.csv')
pipi.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
pipi.describe()
# Out:
#               Age   Education  ...         Income       Miles
# count  180.000000  180.000000  ...     180.000000  180.000000
# mean    28.788889   15.572222  ...   53719.577778  103.194444
# std      6.943498    1.617055  ...   16506.684226   51.863605
# min     18.000000   12.000000  ...   29562.000000   21.000000
# 25%     24.000000   14.000000  ...   44058.750000   66.000000
# 50%     26.000000   16.000000  ...   50596.500000   94.000000
# 75%     33.000000   16.000000  ...   58668.000000  114.750000
# max     50.000000   21.000000  ...  104581.000000  360.000000
#
# [8 rows x 6 columns]

# %%
pipi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
pipi.hist(figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Education'}>],
#        [<AxesSubplot:title={'center':'Usage'}>,
#         <AxesSubplot:title={'center':'Fitness'}>],
#        [<AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Miles'}>]], dtype=object)

# %%
sns.boxenplot(x='Gender',y='Age',data=pipi)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.countplot(x='Product',hue='Gender',data=pipi)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
sns.pairplot(pipi, palette='rocket')

# %%
sns.heatmap(pipi.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn import linear_model
# creating linear regression parameters 

regr = linear_model.LinearRegression()

y = pipi['Miles']
x = pipi[['Usage','Fitness']]

regr.fit(x,y)
regr.coef_
# Out:
# array([20.21486334, 27.20649954])
